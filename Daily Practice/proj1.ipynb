# %%
#pip install pandas seaborn matplotlip gradio ollama

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'titanic_ dataset_final.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# !pip install ollama
# !pip install --upgrade gradio

# %%
import ollama

def generate_insights(df_summary):
    prompt=f'Analyse the dataset summary and provide insights:\n\n{df_summary}'
    response=ollama.chat(model='mistral',messages=[{'role':'user','content':prompt}])
    return response['message']['content']

summary= df.describe().to_string()
insights=generate_insights(summary)
print('\n * AI-Generated insights:\n',insights)
# Out:
#  * AI-Generated insights:
#   This dataset, known as the Titanic passenger lists, contains 891 unique records (PassengerId). Here are some insights based on the summary statistics:
#
# 1. The average (mean) age of passengers is approximately 29.69 years, with a standard deviation of 14.53 years. This indicates a wide range in ages among the passengers.
#
# 2. Approximately 0.384 or 38.4% of passengers survived the sinking of the Titanic. The minimum age is 0.42, and the maximum age is 80. The median (50th percentile) age is 28 years old.
#
# 3. Passengers were primarily in three classes: First Class (Pclass = 1), Second Class (Pclass = 2), or Third Class (Pclass = 3). The mean Pclass is 2.31, which suggests the majority of passengers were traveling in Second Class. However, since Pclass is a continuous variable, this might be due to rounding effects.
#
# ...

# %%
import gradio as gr

def eda_analysis(file):
    df=pd.read_csv(r'titanic_ dataset_final.csv')
    summary=df.describe().to_string()
    insights=generate_insights(summary)
    return insights

demo= gr.Interface(fn=eda_analysis,inputs='file',outputs='text',title='AI-Powered EDA in Mistral')
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://f595ea03ed867e3532.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f595ea03ed867e3532.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
